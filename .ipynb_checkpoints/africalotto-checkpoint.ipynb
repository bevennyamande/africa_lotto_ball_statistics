# %%
import pandas as pd
import numpy as np

# two most interesting urls
URL = 'http://africalotto.co.zw/statistics-bonus-lotto-two'
dataframe = pd.read_html(URL)
tables[0]
# Out:
#     Ball  Frequency      Last Seen
# 0      1         79   4  Draws Ago
# 1      2         69   9  Draws Ago
# 2      3         79   5  Draws Ago
# 3      4         68   5  Draws Ago
# 4      5         72   9  Draws Ago
# 5      6         81   6  Draws Ago
# 6      7         76   8  Draws Ago
# 7      8         73   2  Draws Ago
# 8      9         86  13  Draws Ago
# 9     10         91   4  Draws Ago
# 10    11         83  19  Draws Ago
# 11    12         86   8  Draws Ago
# 12    13         78  13  Draws Ago
# 13    14         73   7  Draws Ago
# 14    15         84    1  Draw Ago
# 15    16         81   3  Draws Ago
# 16    17         74   3  Draws Ago
# 17    18         80    1  Draw Ago
# 18    19         80    1  Draw Ago
# 19    20         68   5  Draws Ago
# 20    21         84   3  Draws Ago
# 21    22         90   9  Draws Ago
# 22    23         80   3  Draws Ago
# 23    24         79   6  Draws Ago
# 24    25         68   3  Draws Ago
# 25    26         88   2  Draws Ago
# ...

# %%
tables[0].describe()
# Out:
#             Ball  Frequency
# count  42.000000  42.000000
# mean   21.500000  78.000000
# std    12.267844   6.803873
# min     1.000000  63.000000
# 25%    11.250000  73.000000
# 50%    21.500000  79.000000
# 75%    31.750000  83.750000
# max    42.000000  91.000000

# %%
tables[0].plot.bar(rot=0, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7be3607fd0>,
# ...
#       dtype=object)
